# %%
def Agecategory():
        if(age<18):
            print("Minor")
            cate="Minor"
        elif(age<60):
            print("Adult")
            cate="Adult"
        else:
            print("Senior Citizen")
            cate="Senior Citizen"
        return cate

# %%
age=int(input("Enter the age: "))
agecate=Agecategory()
# Out:
# Enter the age:  45
# Adult

# %%
print(agecate)
# Out:
# Adult

# %%
# no return
def Agecategorynor():
        if(age<18):
            print("Minor")
            cate="Minor"
        elif(age<60):
            print("Adult")
            cate="Adult"
        else:
            print("Senior Citizen")
            cate="Senior Citizen"

# %%
age=int(input("Enter the age: "))
agecate=Agecategorynor()
# Out:
# Enter the age:  20
# Adult

# %%
print(agecate)
# Out:
# None

# %%
age=int(input("Enter the age: "))
X=Agecategorynor()
# Out:
# Enter the age:  34
# Adult

# %%
def oddeven():
    num=int(input("Enter the number: "))
    if ((num%2) ==1):
        print("Odd Number")
        message=("Odd Number")
    else:
        print("Even Number")
        message=("Even Number")
    return message

# %%
message=oddeven()
# Out:
# Enter the number:  7
# Odd Number

# %%
if(message=="Even Number"):
    print("The given number is even")
else:
    print("The given number is odd")
# Out:
# The given number is odd

# %%
def BMI():
    BMI =float(input("Enter the BMI: "))
    if(BMI<18.5):
        print(f"Underweight")
        BodyMass=("Underweight")
    elif(BMI<24.9):
        print(f"Idealweight")
        BodyMass=("Idealweight")
    elif(BMI<34.9):
        print(f"Overweight") 
        BodyMass=("Overweight")
    else:
        print(f"Obese")
        BodyMass=("Obese")
    return BodyMass

# %%
BodyMass=BMI()
# Out:
# Enter the BMI:  25
# Overweight

# %%
def addition(num1,num2):
    add=num1+num2
    return add

# %%
# non paramedized function(arguments)
addition(num1,num2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 addition(num1,num2)
#
# NameError: name 'addition' is not defined

# %%
# Arguments are given variable directly
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 2
#       1 # Arguments are given variable directly
# ----> 2 addition(10,11)
#
# NameError: name 'addition' is not defined

# %%
addition(10,11)
# Out:
# 21

# %%
def sub(num1,num2):
    sub=num1-num2
    return sub

# %%
sub(22,10)
# Out:
# 12

# %%
class multiplefunctions():
    def oddeven():
        num=int(input("Enter the number: "))
        if ((num%2) ==1):
            print("Odd Number")
            message=("Odd Number")
        else:
            print("Even Number")
            message=("Even Number")
        return message
    def BMI():
        BMI =float(input("Enter the BMI: "))
        if(BMI<18.5):
            print(f"Underweight")
            BodyMass=("Underweight")
        elif(BMI<24.9):
            print(f"Idealweight")
            BodyMass=("Idealweight")
        elif(BMI<34.9):
            print(f"Overweight") 
            BodyMass=("Overweight")
        else:
            print(f"Obese")
            BodyMass=("Obese")
        return BodyMass

# %%
multiplefunctions.BMI()
# Out:
# Enter the BMI:  30
# Overweight
# 'Overweight'

# %%
multiplefunctions.oddeven()
# Out:
# Enter the number:  43
# Odd Number
# 'Odd Number'
