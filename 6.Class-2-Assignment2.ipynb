# %%
from generalfunctions import genfunc

# %%
genfunc.subfields()
# Out:
# Subfields in AI are:
# Machine Learning
# Neural Networks
# Vision
# Robotics
# Speech Processing
# Natural Language Processing

# %%
genfunc.oddeven()
# Out:
# Enter the number:  10
# even number
# 'even number'

# %%
genfunc.Eligible()
# Out:
# Enter the gender:  female
# Enter the age:  17
# not eligible to marry

# %%
genfunc.percentage()
# Out:
# Enter the name:  Raj
# Enter the Subject1 marks:  78
# Enter the Subject2 marks:  87
# Enter the Subject3 marks:  98
# Enter the Subject4marks:  71
# Enter the Subject5 marks:  90
# Total 424
# Percentage is  84.8

# %%
#### genfunc.triangle()
# Out:
# Height:  45
# Breadth:  34
# Area of Triangle:  765.0
# Height1:  46
# Height2:  50
# Breadth2:  78
# Perimeter of the Triangle 174.0
