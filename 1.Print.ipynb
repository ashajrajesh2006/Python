# %%
print("Asha")
# Out:
# Asha

# %%
print("My lovable girl is Br!tn#y R!n@")
# Out:
# My lovable girl is Br!tn#y R!n@

# %%
Print("Ronaald & Rajesh")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 Print("Ronaald & Rajesh")
#
# NameError: name 'Print' is not defined

# %%
print("Ronaald & Rajesh")
# Out:
# Ronaald & Rajesh
