# %%
print("Welcome to Assignment-1")
# Out:
# Welcome to Assignment-1

# %%
#Add 2 given numbers
num1 = 10
num2 = 30
sum = num1 + num2
print("Add = ",sum)
# Out:
# Add =  40

# %%
#Body mass Index
BMI =float(input("Enter the BMI: "))
if(BMI<18.5):
    print(f"Underweight")
elif(BMI<24.9):
    print(f"Idealweight")
elif(BMI<34.9):
        print(f"Overweight")    
else:
    print(f"Obese")
# Out:
# Enter the BMI:  34
# Overweight
