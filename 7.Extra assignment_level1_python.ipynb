# %%
#print statement
print("HOPE AI")
# Out:
# HOPE AI

# %%
#Buy Input
nam=input("Enter your institute name? : ")
# Out:
# Enter your institute name? :  HOPE AI

# %%
#Buy Inputs
nam=input("Enter your name: ")
age=int(input("Enter your age: "))
nam1=input("Enter your school name: ")
deg=input("Enter your degree: ")
# Out:
# Enter your name:  Raj
# Enter your age:  15
# Enter your school name:  Guru School
# Enter your degree:  B.E,CSE

# %%
#Addition
num1 = 43
num2 = 34
sum = num1 + num2
print("add = ",sum)
# Out:
# add =  77

# %%
#Subtraction
num1 = 43
num2 = 34
sub = num1 - num2
print("Sub = ",sub)
# Out:
# Sub =  9

# %%
#Multiplication
num1 = 63
num2 = 97
mul = num1 * num2
print("Mul= ",mul)
# Out:
# Mul=  6111

# %%
#Division - Decimals are also displayed
num1 = 76
num2 = 31
div = num1 / num2
print(f"Float Div= ",div)
# Out:
# Float Div=  2.4516129032258065

# %%
#Floor Division- it will be rouned to the whole number
num1 = 76
num2 = 31
div = num1 // num2
print("Floor Div= ",div)
# Out:
# Floor Div=  2

# %%
#Modulo - calculates the remainder of the operation
num1 = 76
num2 = 31
div = num1 % num2
print("Modulo= ",div)
# Out:
# Modulo=  14

# %%
#Power - exponential operation
a=4
b=4
power = a ** b
print("pow= ",power)
# Out:
# pow=  256
